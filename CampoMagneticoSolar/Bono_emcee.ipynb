# %% [markdown]
# #Ajuste con MCMC usando emcee

# %% [markdown]
# Se muestra el desarrollo para un pixel. Para los 100 pixeles es sólo hacer un for para varios pixeles pero siempre ejecutando el procedimiento que aquí se muestra. Cada uno de los archivos se escribirían las constantes que se obtienen en cada caso. No consideramos necesario hacer el desarrollo completo del problema para emcee ya que se muestra en este notebook el proceso esencial. El resto sería escribir un código que escriba las constantes en un archivo pero este proceso ya se ha hecho en el punto 2a.

# %%
# %pylab inline
import emcee
import pyfits
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sdo = pyfits.open('./data/hmi.m_45s.magnetogram.subregion_x1y1.fits')
time = np.loadtxt("./data/time_series.csv")
data = sdo[0].data
campo = data[:, 135, 235]

# %% [markdown]
# ##Definición de modelos

# %%
def linear_model(x_obs, a, b):
    return x_obs*b + a

# %%
def gauss_model(t,c,d,sigma,mu):
	return c + d*t + (1/(sigma*np.sqrt(2*math.pi)))*np.exp(-0.5*((t-mu)/sigma)**2)

# %%
def step_model(t, f, g, h, n, t_0):
    return f + g*t + h*(1+(2/math.pi)*np.arctan(n*(t-t_0)))

# %% [markdown]
# ##Definicion de funciones para usar emcee

# %% [markdown]
# ###Lnprior

# %%
def linear_lnprior(constantes):
    a, b = constantes
    if -200 < a < 200 and -1 < b < 1:
        return 0.0
    return -inf

# %%
def gauss_lnprior(constantes):
    c, d, sigma, mu= constantes
    if -200 < c < 200 and -1 < d < 1 and 30 < sigma < 50 and 80 < mu < 120 :
        return 0.0
    return -inf

# %%
def step_lnprior(constantes):
    f, g, h, n, t_0 = constantes
    if -200 < f < 200 and -1 < g < 1 and -100 < h < 100 and 0 < n < 100 and 80 < t_0 <350:
        return 0.0
    return -inf

# %% [markdown]
# ###Lnlike

# %%
def linear_lnlike(constantes, time, y_obs):
    a, b = constantes
    y_model = linear_model(time, a, b)
    chi_squared = (1.0/2.0)*sum((y_obs-y_model)**2)
    return -chi_squared

# %%
def gauss_lnlike(constantes, time, y_obs):
    c, d, sigma, mu= constantes
    y_model = gauss_model(time, c, d, sigma, mu)
    chi_squared = (1.0/2.0)*sum((y_obs-y_model)**2)
    return -chi_squared

# %%
def step_lnlike(constantes, time, y_obs):
    f, g, h, n, t_0 = constantes
    y_model = step_model(time, f, g, h, n, t_0)
    chi_squared = (1.0/2.0)*sum((y_obs-y_model)**2)
    return -chi_squared

# %% [markdown]
# ###Lnprob

# %%
def linear_lnprob(constantes, time, y_obs):
    lp = linear_lnprior(constantes)
    if not isfinite(lp):
        return -inf
    return lp +  linear_lnlike(constantes, time, y_obs)

# %%
def gauss_lnprob(constantes, time, y_obs):
    lp = gauss_lnprior(constantes)
    if not isfinite(lp):
        return -inf
    return lp +  gauss_lnlike(constantes, time, y_obs)

# %%
def step_lnprob(constantes, time, y_obs):
    lp = step_lnprior(constantes)
    if not isfinite(lp):
        return -inf
    return lp +  step_lnlike(constantes, time, y_obs)

# %% [markdown]
# ##Inicialización de constantes

# %% [markdown]
# Se inicializan las constantes con un "first guess" de su valor

# %%
a = 0.1
c = 0.1
f = 0.1
b = 0.1
d = 0.1
g = 0.1
h = 0.1
n = 50
t_0 = 210
mu = 100
sigma = 40

# %% [markdown]
# ##Ejecución de emcee

# %% [markdown]
# El archivo que se genera en cada caso contiene los valores de las constantes en toda la caminata. Los valores que se imprimen como constante_fit son el valor que más se repite en la caminata con el número de veces que se repite

# %% [markdown]
# ###Ajuste lineal

# %%
y_lineal = linear_model(time, a, b)
first_guess  = [a, b]

# %%
ndim = 2
nwalkers = 10
n_iterations = 2000

# %%
p_linear = [first_guess + random.randn(ndim) for i in range(nwalkers)]

# %%
linear_sampler = emcee.EnsembleSampler(nwalkers, ndim, linear_lnprob, args=(time, campo))

# %%
linear_sampler.run_mcmc(p_linear, n_iterations, rstate0= random.get_state())
# Out:
# (array([[ 21.93327543,   0.04875298],
#         [ 21.82751421,   0.04944198],
#         [ 22.01817911,   0.04857453],
#         [ 21.98074156,   0.04855641],
#         [ 22.20078193,   0.04818652],
#         [ 21.90485848,   0.048694  ],
#         [ 22.06767141,   0.04837974],
#         [ 22.04689187,   0.04835122],
#         [ 22.16432599,   0.04849268],
#         [ 22.18548731,   0.04768525]]),
#  array([-618.0201719 , -618.42741443, -617.9219034 , -618.02017086,
#         -619.08892479, -618.48649391, -617.98002195, -617.99953867,
#         -619.8502131 , -618.73386653]),
#  ('MT19937', array([4116241185,  882349400, 1360736046, 3729887055, 4042090810,
#           512207930, 2798034770, 4036254870, 2793671886, 3602468169,
#          3617443091, 3502322692, 1693137450, 1247798892,   73420390,
#           223332348,  371302239, 1093262438,  140677130, 1633333620,
#          1466959873, 2797594340, 1663763529,  215811042,  468893196,
#           821843128, 1911456008, 1828053190, 3821581904, 4081704786,
#           275291365, 1487339269,   75611557, 3547584375, 1750914475,
#          1477642453, 2273554444, 2746301587, 3694444933, 2336948225,
#           327521252, 1624164166, 2895647010, 3837015292, 2817139198,
#          1297996822, 2017326100, 1625233639, 1567972110, 1009727579,
#          3393284173, 4026811019, 1171017745, 1993680921, 1283563182,
#          1915039692, 2100799583, 1880128326, 4025545280, 1104559253,
#          2429330214, 3943708680, 3392178361,  128271786, 2910090120,
#          2156189356, 1338821937, 1192214969, 3935784940, 3456836970,
#           263142617, 3627715348,  735955562, 1545198953, 2357658689,
#          2436684507, 4044575260, 3400425905, 4231177096, 1442863812,
#          2278649616, 2600606465, 3383615424, 2402946958, 4294070655,
#          1155364413, 3681717354, 4204167655, 3204741372,  154443686,
#          2497423638, 4136861466, 4284649681, 2359245488, 2293134930,
#           973379346, 3253544935, 3409140791, 3014554575, 2769439838,
#          2450012026, 2325394095, 1859541464, 3564070020, 4223563363,
#          3119923198, 3620573788,  105822597,  310724701, 2055579850,
#           277715253, 3900833284, 1543302061, 3265439651,  944691005,
#           519141373, 2588370196, 3210000685, 3676974943, 3361300658,
#          2490615403,  581841685, 1355366665, 2076190474, 2096466631,
#          1293199113, 1419957610, 3456350536, 3138302711, 4096434821,
#          3464989443, 2904354473, 2573120656, 3569809001, 1278425472,
#          3924188840, 4289159067, 3423022424,  960764147,   25057137,
#          2319455273, 2856127348, 2677231861, 1644462484, 3106961662,
#           868288001,    6381955, 1300224747, 2557805816, 1433338070,
#          2757885439,  296489025, 2296025424, 1990176561, 1609090375,
#          1918056408, 2849710111, 3976710279, 1651109300, 3116730882,
#           481435599,  744262397, 2525594091,  535467576, 1599520232,
#          1972207669, 2210329217, 2260875619,  853268820,  645237357,
#          1250043764, 1148428084,  186215719, 2443633451, 2420992623,
#          3460050163,  902473144, 3610619486, 2330622546, 2831663827,
#           254458334, 2387114288, 1128550887, 2420845466, 3087065939,
#          3484275014,  510052871, 3021494867, 1799628805, 2905964388,
#          2487934626,  716851559, 1535880207, 1843906506,  211784089,
#          3216131680, 2325350229, 2193748097, 1179343786, 2423912855,
#           450245521,   44576733, 1976646917,  172787373,  347048992,
#          2761582495,  127534684,  806647883, 3270115053, 3257360350,
#          1916533172, 4078108322, 3228482920, 1296595603, 3456341626,
#          4226810478, 4123166080, 1103703668, 3896841772,  319337364,
#          2885506939,  852801568, 2423111278,  612079170, 3527369415,
#          3289430120,  874931276, 3985396074, 2747500797, 2773656120,
#          3168616693, 2080680949, 2730895909, 1399188633,  981090299,
#           726434543, 1339716776, 2232007083, 1302280317, 3644749879,
#          4210514157, 2930720652, 3783508820, 2579082625, 4065491491,
#          1010225917, 2158528585,  359542182, 2024180484, 4121119583,
#          3743137501, 3572695167, 2259224928, 1698137897, 3587424717,
#          4096414316, 3798812922,  697733836,  256391788, 1999316029,
#          3949533469, 2567974323,  225081575, 3961574750, 1600453074,
#           660318004, 3636889991,  733136468, 1730478821,   83107331,
#          3725231313, 1589156115, 1732313134, 2968572073,  394123409,
#          2845244127, 2688656733, 2529156362, 4169875473, 1831836437,
#          1917661386, 4225336620,  594414040, 2426986442, 3258653307,
#          2363351163,  185949911, 1612796196, 3805883159, 2724408336,
#           759832987,  865856291, 1503063985,  944214911, 4033463638,
#           188230391,  163988838, 1127192577, 2296117543, 1516333287,
#           325915262, 1208767245, 3824078246,  711922936, 3202417217,
#          3064415162, 1670882367, 2140923222,  853662388, 4046880835,
#           498956974, 3070306584, 1976572602, 2291225615, 1700405234,
#          1929851252, 3696556772, 4053138617,  366620960, 3190832945,
#          2525870224, 2045785205, 2052712166, 3276456720, 4130243463,
#          3518166844, 2169169789, 1750615072, 3979771601, 2487242256,
#          1212797698,  530744866, 3866868926,  568310226, 3695366936,
#           404920593, 1891210087, 1078204464, 1793927473,  704811670,
#          1664017695, 4138144687, 3501691329, 3040803875,  879899822,
#          2761267056, 3298031693, 3710601853, 2593177362, 2206355044,
#           412025440, 4269178674, 3374217634,  620147406, 2203921171,
#          4243006787, 1940033116, 1192994189, 1466944746, 2361200100,
#          1803811653,  505505539, 1268286186, 2213473085, 3505409200,
#           971999323, 3598171719,  273278184, 3232223984,  520289810,
#          1638864751, 4266118582, 1771832569, 1702395192, 3921596978,
#           208174184, 3325151151,  191495504, 3312778958, 3544892322,
#          2697665928, 3933838576, 1944840574, 3307828776, 4239610768,
#          4267894272, 1835356685, 3321086710, 3684560676, 4111643363,
#           884258911, 1498509746, 1694442202, 4039707946, 1394397572,
#           130608895, 3047895379, 2047005696, 2740377513, 1803615675,
#           104633233, 2682178473,   17169608, 2623507262,  267686269,
#          1045018545, 2752396536, 3463383704,  535797112,  578010457,
#          3631121961,  473946562, 3491211924, 3075851062, 1635390160,
#          3014329815, 2842270167, 4034076796, 1287413635, 2727603619,
#          2708407971, 3298423945,  464972709,  127640268, 3112062171,
#          3658549169,  574420446,  533736624,  404266376,  143221409,
#          1025229033, 2444892812, 2369693114, 1992890413, 2801309814,
#          4220688323, 3124708789, 2031840178, 3635654164, 1633497847,
#           164349792, 1691322899, 3242194566,  844122395, 3516413591,
#          1844708891, 2522603652, 3743699582,  592099267, 2577789408,
#           599808757, 3017948402, 3602438627, 3223967066, 2829580731,
#          2486345036, 3505009436, 1464237853, 1649624783,   40188578,
#          2899517992, 1512923751, 3756936744, 1496661749, 3646491494,
#           827385320, 3287164697, 2452308302,  793692654, 2144250801,
#          3349904550, 2401637242,   38817598,  151515189, 1098721251,
#          3479013905, 2446530363, 1506379450, 3761020310, 2103157648,
#          1259639976, 2298507277, 4047615033, 3918901276, 4051749629,
#          3348982219, 3305420015, 2925672607, 2245154768, 1679935248,
#           903338931, 4111419597,  244282518,  212999995,  506624686,
#          1209823075, 2575250717, 4071028469,  145587346, 1518516267,
#           315822424, 1565341179, 1893409522, 4165776676, 2523387109,
#          4094943641,   49848501, 3518077463, 2077655170, 4209921415,
#          1040762860, 3133757444,  625012015,  329309983, 1175356683,
#          2056662572, 4013580096,  352423472, 3975770591, 2813684720,
#          2799037758,  567703518,  665440741,  174646577, 1650038104,
#          3369688782, 3390057476, 2089563072, 1566224621, 1500287060,
#          1995640775, 3016927450,  824212418,    9373970, 3618300369,
#          2753954023, 2265887011, 2876401898,  735343296, 2063869429,
#          1201326688, 2463985378,  318722376, 3226258324,  763762316,
#          3018008106, 4143504139, 2688683144, 4055076767,  884542706,
#          1855598272,  524806525, 2645975824, 3667214160, 1096404302,
#          1031823749, 2799273608,  567633640, 1135190667, 4187837972,
#          1188052160, 1064759004,  424583046, 1470194527, 1541968215,
#          1104289918, 2463569988, 1172065116, 3681283431, 1119435641,
#          2912703975, 1921445837, 2268914011,   75895709,  467793358,
#          4017595878,  441410380,  715930870, 1940522893, 3906311072,
#          2237339261,  145058442,  368368762, 3564499614,  707117007,
#          1876357369, 1004894330, 4017951392,  775423714, 4106654770,
#          3991408019, 2445708271, 4256698016, 4141690867, 4203464755,
#            42634134, 2308006805, 3574957198, 2108425229, 2436660007,
#           784371950,  211070132, 1319576853, 4118068120,  961180091,
#           526288751, 2247392458, 2698400101, 4033121871, 4076194306,
#          1679680481, 2349977305,  865051243, 2281845196,  924889410,
#          3963960200,  922896658,  749262867, 2939954893, 3793483145,
#          1964395771, 1024748950,  352260369, 1443884060], dtype=uint32), 52, 0, 0.0))

# %%
linear_samples = linear_sampler.flatchain
savetxt('./emcee_Samples/linear_sampler.dat', linear_samples, delimiter = ',')

# %%
a_list = linear_samples[:, 0].tolist()
a_count = Counter(a_list)
a_fit = a_count.most_common(1) 
print a_fit
# Out:
# [(0.676146542632257, 13)]

# %%
b_list = linear_samples[:, 1].tolist()
b_count = Counter(b_list)
b_fit = b_count.most_common(1) 
print b_fit
# Out:
# [(0.12718387447343105, 13)]

# %% [markdown]
# ###Ajuste gaussiano

# %%
y_gauss = gauss_model(time, c, d, sigma, mu)
first_guess  = [c, d, sigma, mu]

# %%
ndim = 4
nwalkers = 10
n_iterations = 2000

# %%
p_gauss = [first_guess + random.randn(ndim) for i in range(nwalkers)]

# %%
gauss_sampler = emcee.EnsembleSampler(nwalkers, ndim, gauss_lnprob, args=(time, campo))

# %%
gauss_sampler.run_mcmc(p_gauss, n_iterations, rstate0= random.get_state())
# Out:
# (array([[  2.17693810e+01,   4.97000229e-02,   4.57107494e+01,
#            1.19093449e+02],
#         [  2.17759582e+01,   4.99461732e-02,   3.34434347e+01,
#            1.18105142e+02],
#         [  2.16689898e+01,   5.00316979e-02,   4.26783195e+01,
#            1.10482085e+02],
#         [  2.19777358e+01,   4.88930257e-02,   3.54905306e+01,
#            8.92097331e+01],
#         [  2.24135237e+01,   4.74428618e-02,   4.68754986e+01,
#            8.38533931e+01],
#         [  2.16349799e+01,   4.98065209e-02,   4.56784962e+01,
#            1.05384979e+02],
#         [  2.20847178e+01,   4.82368629e-02,   4.96023241e+01,
#            8.03298411e+01],
#         [  2.20104845e+01,   4.82690149e-02,   4.44755442e+01,
#            9.63077232e+01],
#         [  2.21046945e+01,   4.81002224e-02,   3.13089650e+01,
#            9.56734092e+01],
#         [  2.16942433e+01,   4.96342285e-02,   3.65710642e+01,
#            9.35434493e+01]]),
#  array([-618.72797374, -620.06031772, -619.252283  , -618.25648138,
#         -620.9812661 , -619.45964848, -618.16909403, -618.59982766,
#         -618.23574341, -619.00970539]),
#  ('MT19937', array([4116241185,  882349400, 1360736046, 3729887055, 4042090810,
#           512207930, 2798034770, 4036254870, 2793671886, 3602468169,
#          3617443091, 3502322692, 1693137450, 1247798892,   73420390,
#           223332348,  371302239, 1093262438,  140677130, 1633333620,
#          1466959873, 2797594340, 1663763529,  215811042,  468893196,
#           821843128, 1911456008, 1828053190, 3821581904, 4081704786,
#           275291365, 1487339269,   75611557, 3547584375, 1750914475,
#          1477642453, 2273554444, 2746301587, 3694444933, 2336948225,
#           327521252, 1624164166, 2895647010, 3837015292, 2817139198,
#          1297996822, 2017326100, 1625233639, 1567972110, 1009727579,
#          3393284173, 4026811019, 1171017745, 1993680921, 1283563182,
#          1915039692, 2100799583, 1880128326, 4025545280, 1104559253,
#          2429330214, 3943708680, 3392178361,  128271786, 2910090120,
#          2156189356, 1338821937, 1192214969, 3935784940, 3456836970,
#           263142617, 3627715348,  735955562, 1545198953, 2357658689,
#          2436684507, 4044575260, 3400425905, 4231177096, 1442863812,
#          2278649616, 2600606465, 3383615424, 2402946958, 4294070655,
#          1155364413, 3681717354, 4204167655, 3204741372,  154443686,
#          2497423638, 4136861466, 4284649681, 2359245488, 2293134930,
#           973379346, 3253544935, 3409140791, 3014554575, 2769439838,
#          2450012026, 2325394095, 1859541464, 3564070020, 4223563363,
#          3119923198, 3620573788,  105822597,  310724701, 2055579850,
#           277715253, 3900833284, 1543302061, 3265439651,  944691005,
#           519141373, 2588370196, 3210000685, 3676974943, 3361300658,
#          2490615403,  581841685, 1355366665, 2076190474, 2096466631,
#          1293199113, 1419957610, 3456350536, 3138302711, 4096434821,
#          3464989443, 2904354473, 2573120656, 3569809001, 1278425472,
#          3924188840, 4289159067, 3423022424,  960764147,   25057137,
#          2319455273, 2856127348, 2677231861, 1644462484, 3106961662,
#           868288001,    6381955, 1300224747, 2557805816, 1433338070,
#          2757885439,  296489025, 2296025424, 1990176561, 1609090375,
#          1918056408, 2849710111, 3976710279, 1651109300, 3116730882,
#           481435599,  744262397, 2525594091,  535467576, 1599520232,
#          1972207669, 2210329217, 2260875619,  853268820,  645237357,
#          1250043764, 1148428084,  186215719, 2443633451, 2420992623,
#          3460050163,  902473144, 3610619486, 2330622546, 2831663827,
#           254458334, 2387114288, 1128550887, 2420845466, 3087065939,
#          3484275014,  510052871, 3021494867, 1799628805, 2905964388,
#          2487934626,  716851559, 1535880207, 1843906506,  211784089,
#          3216131680, 2325350229, 2193748097, 1179343786, 2423912855,
#           450245521,   44576733, 1976646917,  172787373,  347048992,
#          2761582495,  127534684,  806647883, 3270115053, 3257360350,
#          1916533172, 4078108322, 3228482920, 1296595603, 3456341626,
#          4226810478, 4123166080, 1103703668, 3896841772,  319337364,
#          2885506939,  852801568, 2423111278,  612079170, 3527369415,
#          3289430120,  874931276, 3985396074, 2747500797, 2773656120,
#          3168616693, 2080680949, 2730895909, 1399188633,  981090299,
#           726434543, 1339716776, 2232007083, 1302280317, 3644749879,
#          4210514157, 2930720652, 3783508820, 2579082625, 4065491491,
#          1010225917, 2158528585,  359542182, 2024180484, 4121119583,
#          3743137501, 3572695167, 2259224928, 1698137897, 3587424717,
#          4096414316, 3798812922,  697733836,  256391788, 1999316029,
#          3949533469, 2567974323,  225081575, 3961574750, 1600453074,
#           660318004, 3636889991,  733136468, 1730478821,   83107331,
#          3725231313, 1589156115, 1732313134, 2968572073,  394123409,
#          2845244127, 2688656733, 2529156362, 4169875473, 1831836437,
#          1917661386, 4225336620,  594414040, 2426986442, 3258653307,
#          2363351163,  185949911, 1612796196, 3805883159, 2724408336,
#           759832987,  865856291, 1503063985,  944214911, 4033463638,
#           188230391,  163988838, 1127192577, 2296117543, 1516333287,
#           325915262, 1208767245, 3824078246,  711922936, 3202417217,
#          3064415162, 1670882367, 2140923222,  853662388, 4046880835,
#           498956974, 3070306584, 1976572602, 2291225615, 1700405234,
#          1929851252, 3696556772, 4053138617,  366620960, 3190832945,
#          2525870224, 2045785205, 2052712166, 3276456720, 4130243463,
#          3518166844, 2169169789, 1750615072, 3979771601, 2487242256,
#          1212797698,  530744866, 3866868926,  568310226, 3695366936,
#           404920593, 1891210087, 1078204464, 1793927473,  704811670,
#          1664017695, 4138144687, 3501691329, 3040803875,  879899822,
#          2761267056, 3298031693, 3710601853, 2593177362, 2206355044,
#           412025440, 4269178674, 3374217634,  620147406, 2203921171,
#          4243006787, 1940033116, 1192994189, 1466944746, 2361200100,
#          1803811653,  505505539, 1268286186, 2213473085, 3505409200,
#           971999323, 3598171719,  273278184, 3232223984,  520289810,
#          1638864751, 4266118582, 1771832569, 1702395192, 3921596978,
#           208174184, 3325151151,  191495504, 3312778958, 3544892322,
#          2697665928, 3933838576, 1944840574, 3307828776, 4239610768,
#          4267894272, 1835356685, 3321086710, 3684560676, 4111643363,
#           884258911, 1498509746, 1694442202, 4039707946, 1394397572,
#           130608895, 3047895379, 2047005696, 2740377513, 1803615675,
#           104633233, 2682178473,   17169608, 2623507262,  267686269,
#          1045018545, 2752396536, 3463383704,  535797112,  578010457,
#          3631121961,  473946562, 3491211924, 3075851062, 1635390160,
#          3014329815, 2842270167, 4034076796, 1287413635, 2727603619,
#          2708407971, 3298423945,  464972709,  127640268, 3112062171,
#          3658549169,  574420446,  533736624,  404266376,  143221409,
#          1025229033, 2444892812, 2369693114, 1992890413, 2801309814,
#          4220688323, 3124708789, 2031840178, 3635654164, 1633497847,
#           164349792, 1691322899, 3242194566,  844122395, 3516413591,
#          1844708891, 2522603652, 3743699582,  592099267, 2577789408,
#           599808757, 3017948402, 3602438627, 3223967066, 2829580731,
#          2486345036, 3505009436, 1464237853, 1649624783,   40188578,
#          2899517992, 1512923751, 3756936744, 1496661749, 3646491494,
#           827385320, 3287164697, 2452308302,  793692654, 2144250801,
#          3349904550, 2401637242,   38817598,  151515189, 1098721251,
#          3479013905, 2446530363, 1506379450, 3761020310, 2103157648,
#          1259639976, 2298507277, 4047615033, 3918901276, 4051749629,
#          3348982219, 3305420015, 2925672607, 2245154768, 1679935248,
#           903338931, 4111419597,  244282518,  212999995,  506624686,
#          1209823075, 2575250717, 4071028469,  145587346, 1518516267,
#           315822424, 1565341179, 1893409522, 4165776676, 2523387109,
#          4094943641,   49848501, 3518077463, 2077655170, 4209921415,
#          1040762860, 3133757444,  625012015,  329309983, 1175356683,
#          2056662572, 4013580096,  352423472, 3975770591, 2813684720,
#          2799037758,  567703518,  665440741,  174646577, 1650038104,
#          3369688782, 3390057476, 2089563072, 1566224621, 1500287060,
#          1995640775, 3016927450,  824212418,    9373970, 3618300369,
#          2753954023, 2265887011, 2876401898,  735343296, 2063869429,
#          1201326688, 2463985378,  318722376, 3226258324,  763762316,
#          3018008106, 4143504139, 2688683144, 4055076767,  884542706,
#          1855598272,  524806525, 2645975824, 3667214160, 1096404302,
#          1031823749, 2799273608,  567633640, 1135190667, 4187837972,
#          1188052160, 1064759004,  424583046, 1470194527, 1541968215,
#          1104289918, 2463569988, 1172065116, 3681283431, 1119435641,
#          2912703975, 1921445837, 2268914011,   75895709,  467793358,
#          4017595878,  441410380,  715930870, 1940522893, 3906311072,
#          2237339261,  145058442,  368368762, 3564499614,  707117007,
#          1876357369, 1004894330, 4017951392,  775423714, 4106654770,
#          3991408019, 2445708271, 4256698016, 4141690867, 4203464755,
#            42634134, 2308006805, 3574957198, 2108425229, 2436660007,
#           784371950,  211070132, 1319576853, 4118068120,  961180091,
#           526288751, 2247392458, 2698400101, 4033121871, 4076194306,
#          1679680481, 2349977305,  865051243, 2281845196,  924889410,
#          3963960200,  922896658,  749262867, 2939954893, 3793483145,
#          1964395771, 1024748950,  352260369, 1443884060], dtype=uint32), 164, 0, 0.0))

# %%
gauss_samples = gauss_sampler.flatchain
savetxt('./emcee_Samples/gauss_sampler.dat', gauss_samples, delimiter = ',')

# %%
c_list = gauss_samples[:, 0].tolist()
c_count = Counter(c_list)
c_fit = c_count.most_common(1) 
print c_fit
# Out:
# [(-0.7371313631687691, 2000)]

# %%
d_list = gauss_samples[:, 1].tolist()
d_count = Counter(d_list)
d_fit = d_count.most_common(1) 
print d_fit
# Out:
# [(2.3887857234210177, 2000)]

# %%
sigma_list = gauss_samples[:, 2].tolist()
sigma_count = Counter(sigma_list)
sigma_fit = sigma_count.most_common(1) 
print sigma_fit
# Out:
# [(40.66080334310102, 2000)]

# %%
mu_list = gauss_samples[:, 3].tolist()
mu_count = Counter(mu_list)
mu_fit = mu_count.most_common(1) 
print mu_fit
# Out:
# [(99.94092801232333, 2000)]

# %% [markdown]
# ###Ajuste de paso

# %%
y_step = step_model(time, f, g, h, n, t_0)
first_guess  = [f, g, h, n, t_0]

# %%
ndim = 5
nwalkers = 10
n_iterations = 2000

# %%
p_step = [first_guess + random.randn(ndim) for i in range(nwalkers)]

# %%
step_sampler = emcee.EnsembleSampler(nwalkers, ndim, step_lnprob, args=(time, campo))

# %%
step_sampler.run_mcmc(p_step, n_iterations, rstate0= random.get_state())
# Out:
# (array([[  2.17350375e+01,   5.33665704e-02,  -5.98286516e-01,
#            7.41081172e+01,   2.10625671e+02],
#         [  2.16044556e+01,   5.51598640e-02,  -7.27041721e-01,
#            3.32318665e+01,   2.09919943e+02],
#         [  2.17287829e+01,   5.38280112e-02,  -6.57491022e-01,
#            1.29812258e+01,   2.08951947e+02],
#         [  2.19079897e+01,   5.25059758e-02,  -6.06206093e-01,
#            8.67567713e+01,   2.09854415e+02],
#         [  2.12291290e+01,   5.66370480e-02,  -8.33027222e-01,
#            6.79211345e+01,   2.09572320e+02],
#         [  2.16653339e+01,   5.37217185e-02,  -6.64983313e-01,
#            2.01959601e+01,   2.09703247e+02],
#         [  2.14557194e+01,   5.55834108e-02,  -8.31360978e-01,
#            1.17220742e+01,   2.10838093e+02],
#         [  2.13182104e+01,   5.47303296e-02,  -6.57926034e-01,
#            9.87262626e+01,   2.08856822e+02],
#         [  2.18281775e+01,   5.31143044e-02,  -6.69742778e-01,
#            9.29848266e+01,   2.10035997e+02],
#         [  2.19340605e+01,   5.21141736e-02,  -5.68305581e-01,
#            4.55697171e+01,   2.09600249e+02]]),
#  array([-596.28317254, -598.54128882, -596.31116347, -595.81417155,
#         -598.0271419 , -595.360381  , -598.69872631, -598.85360591,
#         -595.78788707, -596.41076904]),
#  ('MT19937', array([4116241185,  882349400, 1360736046, 3729887055, 4042090810,
#           512207930, 2798034770, 4036254870, 2793671886, 3602468169,
#          3617443091, 3502322692, 1693137450, 1247798892,   73420390,
#           223332348,  371302239, 1093262438,  140677130, 1633333620,
#          1466959873, 2797594340, 1663763529,  215811042,  468893196,
#           821843128, 1911456008, 1828053190, 3821581904, 4081704786,
#           275291365, 1487339269,   75611557, 3547584375, 1750914475,
#          1477642453, 2273554444, 2746301587, 3694444933, 2336948225,
#           327521252, 1624164166, 2895647010, 3837015292, 2817139198,
#          1297996822, 2017326100, 1625233639, 1567972110, 1009727579,
#          3393284173, 4026811019, 1171017745, 1993680921, 1283563182,
#          1915039692, 2100799583, 1880128326, 4025545280, 1104559253,
#          2429330214, 3943708680, 3392178361,  128271786, 2910090120,
#          2156189356, 1338821937, 1192214969, 3935784940, 3456836970,
#           263142617, 3627715348,  735955562, 1545198953, 2357658689,
#          2436684507, 4044575260, 3400425905, 4231177096, 1442863812,
#          2278649616, 2600606465, 3383615424, 2402946958, 4294070655,
#          1155364413, 3681717354, 4204167655, 3204741372,  154443686,
#          2497423638, 4136861466, 4284649681, 2359245488, 2293134930,
#           973379346, 3253544935, 3409140791, 3014554575, 2769439838,
#          2450012026, 2325394095, 1859541464, 3564070020, 4223563363,
#          3119923198, 3620573788,  105822597,  310724701, 2055579850,
#           277715253, 3900833284, 1543302061, 3265439651,  944691005,
#           519141373, 2588370196, 3210000685, 3676974943, 3361300658,
#          2490615403,  581841685, 1355366665, 2076190474, 2096466631,
#          1293199113, 1419957610, 3456350536, 3138302711, 4096434821,
#          3464989443, 2904354473, 2573120656, 3569809001, 1278425472,
#          3924188840, 4289159067, 3423022424,  960764147,   25057137,
#          2319455273, 2856127348, 2677231861, 1644462484, 3106961662,
#           868288001,    6381955, 1300224747, 2557805816, 1433338070,
#          2757885439,  296489025, 2296025424, 1990176561, 1609090375,
#          1918056408, 2849710111, 3976710279, 1651109300, 3116730882,
#           481435599,  744262397, 2525594091,  535467576, 1599520232,
#          1972207669, 2210329217, 2260875619,  853268820,  645237357,
#          1250043764, 1148428084,  186215719, 2443633451, 2420992623,
#          3460050163,  902473144, 3610619486, 2330622546, 2831663827,
#           254458334, 2387114288, 1128550887, 2420845466, 3087065939,
#          3484275014,  510052871, 3021494867, 1799628805, 2905964388,
#          2487934626,  716851559, 1535880207, 1843906506,  211784089,
#          3216131680, 2325350229, 2193748097, 1179343786, 2423912855,
#           450245521,   44576733, 1976646917,  172787373,  347048992,
#          2761582495,  127534684,  806647883, 3270115053, 3257360350,
#          1916533172, 4078108322, 3228482920, 1296595603, 3456341626,
#          4226810478, 4123166080, 1103703668, 3896841772,  319337364,
#          2885506939,  852801568, 2423111278,  612079170, 3527369415,
#          3289430120,  874931276, 3985396074, 2747500797, 2773656120,
#          3168616693, 2080680949, 2730895909, 1399188633,  981090299,
#           726434543, 1339716776, 2232007083, 1302280317, 3644749879,
#          4210514157, 2930720652, 3783508820, 2579082625, 4065491491,
#          1010225917, 2158528585,  359542182, 2024180484, 4121119583,
#          3743137501, 3572695167, 2259224928, 1698137897, 3587424717,
#          4096414316, 3798812922,  697733836,  256391788, 1999316029,
#          3949533469, 2567974323,  225081575, 3961574750, 1600453074,
#           660318004, 3636889991,  733136468, 1730478821,   83107331,
#          3725231313, 1589156115, 1732313134, 2968572073,  394123409,
#          2845244127, 2688656733, 2529156362, 4169875473, 1831836437,
#          1917661386, 4225336620,  594414040, 2426986442, 3258653307,
#          2363351163,  185949911, 1612796196, 3805883159, 2724408336,
#           759832987,  865856291, 1503063985,  944214911, 4033463638,
#           188230391,  163988838, 1127192577, 2296117543, 1516333287,
#           325915262, 1208767245, 3824078246,  711922936, 3202417217,
#          3064415162, 1670882367, 2140923222,  853662388, 4046880835,
#           498956974, 3070306584, 1976572602, 2291225615, 1700405234,
#          1929851252, 3696556772, 4053138617,  366620960, 3190832945,
#          2525870224, 2045785205, 2052712166, 3276456720, 4130243463,
#          3518166844, 2169169789, 1750615072, 3979771601, 2487242256,
#          1212797698,  530744866, 3866868926,  568310226, 3695366936,
#           404920593, 1891210087, 1078204464, 1793927473,  704811670,
#          1664017695, 4138144687, 3501691329, 3040803875,  879899822,
#          2761267056, 3298031693, 3710601853, 2593177362, 2206355044,
#           412025440, 4269178674, 3374217634,  620147406, 2203921171,
#          4243006787, 1940033116, 1192994189, 1466944746, 2361200100,
#          1803811653,  505505539, 1268286186, 2213473085, 3505409200,
#           971999323, 3598171719,  273278184, 3232223984,  520289810,
#          1638864751, 4266118582, 1771832569, 1702395192, 3921596978,
#           208174184, 3325151151,  191495504, 3312778958, 3544892322,
#          2697665928, 3933838576, 1944840574, 3307828776, 4239610768,
#          4267894272, 1835356685, 3321086710, 3684560676, 4111643363,
#           884258911, 1498509746, 1694442202, 4039707946, 1394397572,
#           130608895, 3047895379, 2047005696, 2740377513, 1803615675,
#           104633233, 2682178473,   17169608, 2623507262,  267686269,
#          1045018545, 2752396536, 3463383704,  535797112,  578010457,
#          3631121961,  473946562, 3491211924, 3075851062, 1635390160,
#          3014329815, 2842270167, 4034076796, 1287413635, 2727603619,
#          2708407971, 3298423945,  464972709,  127640268, 3112062171,
#          3658549169,  574420446,  533736624,  404266376,  143221409,
#          1025229033, 2444892812, 2369693114, 1992890413, 2801309814,
#          4220688323, 3124708789, 2031840178, 3635654164, 1633497847,
#           164349792, 1691322899, 3242194566,  844122395, 3516413591,
#          1844708891, 2522603652, 3743699582,  592099267, 2577789408,
#           599808757, 3017948402, 3602438627, 3223967066, 2829580731,
#          2486345036, 3505009436, 1464237853, 1649624783,   40188578,
#          2899517992, 1512923751, 3756936744, 1496661749, 3646491494,
#           827385320, 3287164697, 2452308302,  793692654, 2144250801,
#          3349904550, 2401637242,   38817598,  151515189, 1098721251,
#          3479013905, 2446530363, 1506379450, 3761020310, 2103157648,
#          1259639976, 2298507277, 4047615033, 3918901276, 4051749629,
#          3348982219, 3305420015, 2925672607, 2245154768, 1679935248,
#           903338931, 4111419597,  244282518,  212999995,  506624686,
#          1209823075, 2575250717, 4071028469,  145587346, 1518516267,
#           315822424, 1565341179, 1893409522, 4165776676, 2523387109,
#          4094943641,   49848501, 3518077463, 2077655170, 4209921415,
#          1040762860, 3133757444,  625012015,  329309983, 1175356683,
#          2056662572, 4013580096,  352423472, 3975770591, 2813684720,
#          2799037758,  567703518,  665440741,  174646577, 1650038104,
#          3369688782, 3390057476, 2089563072, 1566224621, 1500287060,
#          1995640775, 3016927450,  824212418,    9373970, 3618300369,
#          2753954023, 2265887011, 2876401898,  735343296, 2063869429,
#          1201326688, 2463985378,  318722376, 3226258324,  763762316,
#          3018008106, 4143504139, 2688683144, 4055076767,  884542706,
#          1855598272,  524806525, 2645975824, 3667214160, 1096404302,
#          1031823749, 2799273608,  567633640, 1135190667, 4187837972,
#          1188052160, 1064759004,  424583046, 1470194527, 1541968215,
#          1104289918, 2463569988, 1172065116, 3681283431, 1119435641,
#          2912703975, 1921445837, 2268914011,   75895709,  467793358,
#          4017595878,  441410380,  715930870, 1940522893, 3906311072,
#          2237339261,  145058442,  368368762, 3564499614,  707117007,
#          1876357369, 1004894330, 4017951392,  775423714, 4106654770,
#          3991408019, 2445708271, 4256698016, 4141690867, 4203464755,
#            42634134, 2308006805, 3574957198, 2108425229, 2436660007,
#           784371950,  211070132, 1319576853, 4118068120,  961180091,
#           526288751, 2247392458, 2698400101, 4033121871, 4076194306,
#          1679680481, 2349977305,  865051243, 2281845196,  924889410,
#          3963960200,  922896658,  749262867, 2939954893, 3793483145,
#          1964395771, 1024748950,  352260369, 1443884060], dtype=uint32), 496, 0, 0.0))

# %%
step_samples = step_sampler.flatchain
savetxt('./emcee_Samples/gauss_sampler.dat', gauss_samples, delimiter = ',')

# %%
f_list = step_samples[:, 0].tolist()
f_count = Counter(f_list)
f_fit = f_count.most_common(1) 
print f_fit
# Out:
# [(22.032488676864066, 22)]

# %%
g_list = step_samples[:, 1].tolist()
g_count = Counter(g_list)
g_fit = g_count.most_common(1) 
print g_fit
# Out:
# [(0.05291860863739551, 22)]

# %%
h_list = step_samples[:, 2].tolist()
h_count = Counter(h_list)
h_fit = h_count.most_common(1) 
print h_fit
# Out:
# [(-0.7303862585450296, 22)]

# %%
n_list = step_samples[:, 3].tolist()
n_count = Counter(n_list)
n_fit = n_count.most_common(1) 
print n_fit
# Out:
# [(99.83810083296488, 22)]

# %%
t0_list = step_samples[:, 4].tolist()
t0_count = Counter(t0_list)
t0_fit = t0_count.most_common(1) 
print t0_fit
# Out:
# [(209.6467837714025, 22)]
